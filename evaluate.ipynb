# %%
# -*-Encoding: utf-8 -*-
################################################################################
#
# Copyright (c) 2022 Baidu.com, Inc. All Rights Reserved
#
################################################################################
"""
Description: Evaluate the performance
Authors: Lu,Xinjiang (luxinjiang@baidu.com)
Date:    2022/03/10
"""
import os
import sys
import time
import traceback
import numpy as np
import metrics
from prepare import prep_env


class Loader(object):
    """
    Desc:
        Dynamically Load a Module
    """
    def __init__(self):
        """
        """
        pass

    @staticmethod
    def load(path):
        """
        Args:
            path to the script
        """
        try:
            items = os.path.split(path)
            sys.path.append(os.path.join(*items[:-1]))
            ip_module = __import__(items[-1][:-3])
            return ip_module
        except Exception as error:
            print("IMPORT ERROR: ", error)
            print("Load module [path %s] error: %s" % (path, traceback.format_exc()))
            traceback.print_exc()
            return None


def evaluate(settings):
    # type: (dict) -> float
    """
    Desc:
        Test the performance on the whole wind farm
    Args:
        settings:
    Returns:
        A score
    """
    start_forecast_time = time.time()
    forecast_module = Loader.load(settings["pred_file"])
    predictions, grounds, raw_data_lst = forecast_module.forecast(settings)
    end_forecast_time = time.time()
    if settings["is_debug"]:
        print("\nElapsed time for prediction is: {} secs\n".format(end_forecast_time - start_forecast_time))

    preds = np.array(predictions)
    gts = np.array(grounds)
    preds = np.sum(preds, axis=0)
    gts = np.sum(gts, axis=0)

    # A convenient customized relative metric can be adopted
    # to evaluate the 'accuracy'-like performance of developed model for Wind Power forecasting problem
    day_len = settings["day_len"]
    day_acc = []
    for idx in range(0, preds.shape[0]):
        acc = 1 - metrics.rmse(preds[idx, -day_len:, -1], gts[idx, -day_len:, -1]) / (settings["capacity"] * 1000)
        if acc != acc:
            continue
        day_acc.append(acc)
    day_acc = np.array(day_acc).mean()
    print('Accuracy:  {:.4f}%'.format(day_acc * 100))
    # NOTE: Before calculating the metrics, the unit of the outcome (e.g. predicted or true) power
    #       should be converted from Kilo Watt to Mega Watt first.
    # out_len = settings["output_len"]
    # mae, rmse = metrics.regressor_scores(predictions[:, -out_len:, :] / 1000, grounds[:, -out_len:, :] / 1000)

    overall_mae, overall_rmse = metrics.regressor_detailed_scores(predictions, grounds, raw_data_lst, settings)

    print('\n \t RMSE: {}, MAE: {}'.format(overall_rmse, overall_mae))

    if settings["is_debug"]:
        end_test_time = time.time()
        print("\nElapsed time for evaluation is {} secs\n".format(end_test_time - end_forecast_time))

    total_score = (overall_mae + overall_rmse) / 2
    return total_score


if __name__ == "__main__":
    # Set up the initial environment
    # Current settings for the model
    envs = prep_env()
    score = evaluate(envs)
    print('\n --- Overall Score --- \n\t{}'.format(score))
# Out:
# Experimental settings are:
# {'data_path': './data/', 'filename': 'wtbdata_245days.csv', 'task': 'MS', 'target': 'Patv', 'checkpoints': './checkpoints/', 'input_len': 144, 'output_len': 288, 'start_col': 3, 'in_var': 10, 'out_var': 1, 'day_len': 144, 'train_size': 153, 'val_size': 16, 'test_size': 15, 'total_size': 184, 'lstm_layer': 2, 'dropout': 0.05, 'num_workers': 5, 'train_epochs': 10, 'batch_size': 32, 'patience': 3, 'lr': 0.0001, 'lr_adjust': 'type1', 'capacity': 134, 'turbine_id': 0, 'pred_file': './predict.py', 'stride': 1, 'is_debug': False}
# >>>>>>> Forecasting Turbine   0 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   1 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   2 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   3 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   4 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   5 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   6 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   7 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   8 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine   9 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  10 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  11 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  12 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  13 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  14 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  15 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  16 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  17 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  18 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  19 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  20 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  21 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  22 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  23 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  24 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  25 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  26 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  27 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  28 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  29 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  30 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  31 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  32 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  33 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  34 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  35 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  36 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  37 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  38 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  39 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  40 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  41 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  42 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  43 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  44 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  45 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  46 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  47 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  48 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  49 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  50 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  51 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  52 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  53 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  54 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  55 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  56 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  57 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  58 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  59 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  60 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  61 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  62 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  63 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  64 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  65 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  66 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  67 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  68 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  69 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  70 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  71 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  72 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  73 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  74 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  75 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  76 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  77 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  78 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  79 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  80 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  81 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  82 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  83 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  84 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  85 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  86 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  87 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  88 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  89 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  90 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  91 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  92 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  93 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  94 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  95 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  96 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  97 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  98 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine  99 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 100 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 101 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 102 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 103 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 104 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 105 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 106 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 107 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 108 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 109 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 110 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 111 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 112 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 113 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 114 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 115 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 116 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 117 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 118 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 119 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 120 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 121 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 122 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 123 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 124 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 125 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 126 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 127 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 128 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 129 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 130 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 131 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 132 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# >>>>>>> Forecasting Turbine 133 >>>>>>>>>>>>>>>>>>>>>>>>>>
#
# Accuracy:  95.2188%
#
#  	 RMSE: 54.76303710536791, MAE: 44.43932695686717
#
#  --- Overall Score ---
# 	49.60118203111754
